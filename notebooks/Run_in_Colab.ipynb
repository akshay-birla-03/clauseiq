# %% [markdown]
# # ClauseIQ — Agentic RAG (one-click run)
#
# Ingests synthetic contracts and answers a question with clause-level citations (offline extractive backend).
#
# Press **Runtime -> Run all** (or run each cell top to bottom).

# %%
# !git clone https://github.com/akshay-birla-03/clauseiq.git
# %cd clauseiq

# %%
# !pip install -q -e .

# %% [markdown]
# ### Run the demo

# %%
# !python scripts/generate_contracts.py

# %%
# !clauseiq ask "What is the termination notice period and the breach cure window?"
